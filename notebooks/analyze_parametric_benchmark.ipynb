# %%
import pandas as pd
csv = pd.read_csv("../benchmark_parametric_methods_aggregate - Copy.csv")

# %%
csv
# Out:
#                                                   path sampling_mode  \
# 0    E:\MSImaging-data\_msi_visual\Extractions\NRL4...        random
# 1    E:\MSImaging-data\_msi_visual\Extractions\NRL4...        random
# 2    E:\MSImaging-data\_msi_visual\Extractions\NRL4...        random
# 3    E:\MSImaging-data\_msi_visual\Extractions\NRL4...    superpixel
# 4    E:\MSImaging-data\_msi_visual\Extractions\NRL4...    superpixel
# ..                                                 ...           ...
# 205  E:\MSImaging-data\_msi_visual\Extractions\PXD0...        random
# 206  E:\MSImaging-data\_msi_visual\Extractions\PXD0...        random
# 207  E:\MSImaging-data\_msi_visual\Extractions\PXD0...    superpixel
# 208  E:\MSImaging-data\_msi_visual\Extractions\PXD0...    superpixel
# 209  E:\MSImaging-data\_msi_visual\Extractions\PXD0...    superpixel
#
#                   method  n_repeats  sampling_num_samples_mean  \
# 0    parametric_mics_lmc          1                     5000.0
# ...
